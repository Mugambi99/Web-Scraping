# %%
import requests
import bs4
from bs4 import BeautifulSoup
import random
from time import sleep

# %%
url ="https://www.fuzu.com/kenya/job?filters[term]=data%20science&filters[job_id]=464311&page=1"

# %%
headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"
}

# %%
response=requests.get(url, {"Headers":headers})

response.status_code
# Out:
# 200

# %%
soup=bs4.BeautifulSoup(response.text, "html.parser")

# %%
# creating multiple pages
url_path = 'https://www.fuzu.com/kenya/job?filters[term]=data%20science&filters[job_id]=464311&page=1'
# Construct your own url paths 
a = 'https://www.fuzu.com/kenya/job?filters[term]=data%20science&filters[job_id]=464311&'
b = 'page='
paths=[]
for i in range(0,20):
    i = str(i)
    path = a+i+b
    paths.append(path)

# %%
institutions=[]
positions=[]
locations=[]
days_left=[]

for page in paths:
    url = page
    result = requests.get(url)
    soup = bs4.BeautifulSoup(result.text,'html.parser')
    institution=soup.find_all('p',{"class":"Text__StyledText-sc-152w2ki-0 MDWeZ b2c-text"})
    position=soup.find_all('h6',{"class":"Title__StyledTitle-sc-5s9ddm-0 cvLYDq title"})
    location=soup.find_all('p',{"class":"Text__StyledText-sc-152w2ki-0 ckLUZM b2c-text"})
    day_left=soup.find_all('p',{"class":"Text__StyledText-sc-152w2ki-0 bpWsQZ b2c-text"})
    sleep(random.randint(2,10))

    for i in institution:
        k=i.text
        institutions.append(k)
    
# print(institutions)

    for i in position:
        p=i.text
        positions.append(p)
    
# print(positions)


    for i in location:
        l=i.text
        locations.append(l)
    
# print(locations)




    for i in day_left:
        d=i.text
        days_left.append(d)
    
# print(days_left)

# %%
import pandas as pd 
ds_data=pd.DataFrame({'Institution':institutions,"Position":positions,"Location":locations,"Days left":days_left})

# %%
data_science={'Institution':institutions,"Position":positions,"Location":locations,"Days left":days_left}
data_science
# Out:
# {'Institution': ['KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited',
#   'KCB Group',
#   'WWF International',
#   'Busara Center for Behavioral Economics',
#   'The Nature Conservancy',
#   'Kamoa App',
#   'Majorel Kenya Limited',
#   'STEPWISE. ',
#   'Anvil Shield Holdings',
#   'Stepwise',
#   'Majorel Kenya Limited'],
#  'Position': ['Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst',
#   'Data Engineer',
#   'Natural Science Coordinator',
#   'Associate - Health',
#   'Africa Blue Carbon Specialist',
#   'Data Scientist',
#   'Reporting Analyst',
#   'Android Developer',
#   'Full Stack Software Developer (C # | Vue JS)',
#   'Laravel Developers',
#   'Information Security Analyst'],
#  'Location': ['Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Kajiado, Kenya',
#   'Nairobi, Kenya',
#   'Mombasa, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya',
#   'Nairobi, Kenya'],
#  'Days left': ['1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining',
#   '1 day remaining',
#   '10 days remaining',
#   '4 days remaining',
#   '6 days remaining',
#   '3 days remaining',
#   '21 days remaining',
#   '1 day remaining',
#   '25 days remaining',
#   '1 day remaining',
#   '9 days remaining']}

# %%
ds_data
# Out:
#                                 Institution  \
# 0                                 KCB Group
# 1                         WWF International
# 2    Busara Center for Behavioral Economics
# 3                    The Nature Conservancy
# 4                                 Kamoa App
# ..                                      ...
# 195                   Majorel Kenya Limited
# 196                              STEPWISE.
# 197                   Anvil Shield Holdings
# 198                                Stepwise
# 199                   Majorel Kenya Limited
#
#                                          Position        Location  \
# 0                                   Data Engineer  Nairobi, Kenya
# 1                     Natural Science Coordinator  Kajiado, Kenya
# 2                              Associate - Health  Nairobi, Kenya
# 3                   Africa Blue Carbon Specialist  Mombasa, Kenya
# 4                                  Data Scientist  Nairobi, Kenya
# ..                                            ...             ...
# 195                             Reporting Analyst  Nairobi, Kenya
# 196                             Android Developer  Nairobi, Kenya
# 197  Full Stack Software Developer (C # | Vue JS)  Nairobi, Kenya
# 198                            Laravel Developers  Nairobi, Kenya
# 199                  Information Security Analyst  Nairobi, Kenya
#
#              Days left
# 0      1 day remaining
# 1    10 days remaining
# 2     4 days remaining
# 3     6 days remaining
# 4     3 days remaining
# ..                 ...
# 195  21 days remaining
# 196    1 day remaining
# 197  25 days remaining
# 198    1 day remaining
# 199   9 days remaining
#
# [200 rows x 4 columns]

# %%
ds_data.to_csv("DataScience_file.csv",sep=',')
ds_data.head(5)
# Out:
#               Institution                       Position        Location  \
# 0               KCB Group                  Data Engineer  Nairobi, Kenya
# 1       WWF International    Natural Science Coordinator  Kajiado, Kenya
# 2  The Nature Conservancy  Africa Blue Carbon Specialist  Mombasa, Kenya
# 3               Kamoa App                 Data Scientist  Nairobi, Kenya
# 4   Majorel Kenya Limited              Reporting Analyst  Nairobi, Kenya
#
#            Days left
# 0    1 day remaining
# 1  10 days remaining
# 2   6 days remaining
# 3   3 days remaining
# 4  21 days remaining

# %%
# Use the !git remote add origin <your GitHub repository URL> command to link your local repository to a remote GitHub repository.

# !git remote add origin https://github.com/Mugambi99/Web-Scraping.git

#Use the !git push -u origin master command to push your local repository to GitHub.

# !git push -u origin master

# !git add .
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git init command to initialize a new git repository.
# !git add command to add the Jupyter Notebook file to the repository.
# !git commit -m "Your commit message" command to commit the changes.
# !git remote add origin <your GitHub repository URL> command to link your local repository to a remote GitHub repository.
# !git push -u origin master command to push your local repository to GitHub.

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/HP/ZINDUA/Web Scraping/.git/

# %%
# !git add .
# Out:
# warning: in the working copy of '.ipynb_checkpoints/Fuzu Jobs scrapping-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/Jumia Web Scrapping-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Fuzu Jobs scrapping.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Jumia Web Scrapping.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git commit -m "Web Scrapping of different websites"
# Out:
# [master (root-commit) 750f59d] Web Scrapping of different websites
#  4 files changed, 2182 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Fuzu Jobs scrapping-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Jumia Web Scrapping-checkpoint.ipynb
#  create mode 100644 Fuzu Jobs scrapping.ipynb
#  create mode 100644 Jumia Web Scrapping.ipynb

# %%
# !git remote add origin https://github.com/Mugambi99/Web-Scraping.git

# %%
# !git push -u origin
# Out:
# fatal: The current branch master has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin master
#
# To have this happen automatically for branches without a tracking
# upstream, see 'push.autoSetupRemote' in 'git help config'.

# %%
# !git push --set-upstream origin master
# Out:
# branch 'master' set up to track 'origin/master'.
# To https://github.com/Mugambi99/Web-Scraping.git
#  * [new branch]      master -> master
